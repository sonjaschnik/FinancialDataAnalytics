# %% [markdown]
# **Class ESG Material**

# %%
companies = ['tesla', 'netflix', 'disney', 'volkswagen']

# %%
import beautifulsoup
import requests
import os
import sys

# %%
class Scrape:
    def __init__(self, name, year, numer_of_close_matches):
        self.name = name
        self.year = year
        self.numer_of_close_matches = numer_of_close_matches_found

    def whoosh(self):
        # scour through the internet and find the materials
        os.save() # download a report file and save it somewhere

        print(f'{self.number_of_close_matches_found} matches for {self.name} have been saved.')

for comp in companies:
    for yr in years:
        Scrape(comp, yr)
