# %% [markdown]
# Homework 6 - Natural Language Processing (nlp)

# %% [markdown]
# Task 1: Sourcing

# %%
# Step 1: Install pdfminer.six if you haven't already
# You can install it using conda or pip, see 
  # https://anaconda.org/conda-forge/pdfminer.six
  # https://pypi.org/project/pdfminer.six/

  # im Terminal eingeben:
  pip install pdfminer.six

# %%
# Step 2: Import the required module

# im Terminal eingeben: python 3 (um python direkt im Terminal zu öffnen), dann:
from pdfminer.high_level import extract_text

# --> es passiert nichts; importiert nur die Funktion

# %%
# Step 3: Extract text from PDF file
extracted_text = extract_text('../homeworks/ruben_2021_eft.pdf')
print(extracted_text[0:80])
